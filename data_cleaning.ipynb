# %%
import re
from typing import Union

from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv("scraped_data/scraped_data.csv")
df
# Out:
#                                               web_url  is_gambling_site  \
# 0               https://www.nikosgreekrestaurant.com/                 1
# 1                        https://www.myrkurmusic.com/                 1
# 2                      https://www.hookedpierbar.com/                 1
# 3                       https://electricfeelgood.com/                 1
# 4                             https://thedinerqc.com/                 1
# ..                                                ...               ...
# 58  https://mediaindonesia.com/politik-dan-hukum/6...                 0
# 59  https://www.cnbcindonesia.com/news/20220802184...                 0
# 60  https://www.bbc.com/indonesia/articles/cg66wyd...                 0
# 61  https://www.inilah.com/11-cara-menghilangkan-k...                 0
# 62  https://infopublik.id/kategori/sorot-politik-h...                 0
#
#     is_error  error_scraping_desc  \
# 0      False                  NaN
# 1      False                  NaN
# 2      False                  NaN
# 3      False                  NaN
# 4      False                  NaN
# ..       ...                  ...
# 58     False                  NaN
# 59     False                  NaN
# 60     False                  NaN
# 61     False                  NaN
# 62     False                  NaN
#
#                                      scraped_elements exception_raised  \
# 0   <html lang="en-US" dir="ltr"><head><title>Just...              NaN
# 1   <html lang="id"><head>\n   <meta http-equiv="C...              NaN
# 2   <html class="no-js" lang="en-US"><!--<![endif]...              NaN
# 3   <html ⚡="" lang="id" amp-version="240906104400...              NaN
# 4   <html xmlns:wormhole="http://www.w3.org/1999/x...              NaN
# ..                                                ...              ...
# 58  <html lang="id"><head>\n<meta charset="UTF-8">...              NaN
# 59  <html lang="id" class="scroll-smooth" data-cri...              NaN
# 60  <html lang="id" class="" dir="ltr"><head><titl...              NaN
# 61  <html lang="en-US" dir="ltr"><head><title>Just...              NaN
# 62  <html lang="id"><head>\n    <!-- Global site t...              NaN
#
#       scraping_initiation_time
# 0   2024-09-23 15:27:17.455269
# 1   2024-09-23 15:27:28.813171
# 2   2024-09-23 15:27:39.131279
# 3   2024-09-23 15:27:51.620380
# 4   2024-09-23 15:28:12.225006
# ..                         ...
# 58  2024-09-23 16:10:43.716552
# 59  2024-09-23 16:10:56.539106
# 60  2024-09-23 16:11:09.260479
# 61  2024-09-23 16:11:19.870977
# 62  2024-09-23 16:11:37.853724
#
# [63 rows x 7 columns]

# %% [markdown]
# # Data Cleaning

# %%
df_clean = df.copy()

# %% [markdown]
# ## Remove rows with error

# %%
df_clean = df_clean[df_clean["is_error"]==False]

# %%
df_clean.head()
# Out:
#                                  web_url  is_gambling_site  is_error  \
# 0  https://www.nikosgreekrestaurant.com/                 1     False
# 1           https://www.myrkurmusic.com/                 1     False
# 2         https://www.hookedpierbar.com/                 1     False
# 3          https://electricfeelgood.com/                 1     False
# 4                https://thedinerqc.com/                 1     False
#
#    error_scraping_desc                                   scraped_elements  \
# 0                  NaN  <html lang="en-US" dir="ltr"><head><title>Just...
# 1                  NaN  <html lang="id"><head>\n   <meta http-equiv="C...
# 2                  NaN  <html class="no-js" lang="en-US"><!--<![endif]...
# 3                  NaN  <html ⚡="" lang="id" amp-version="240906104400...
# 4                  NaN  <html xmlns:wormhole="http://www.w3.org/1999/x...
#
#   exception_raised    scraping_initiation_time
# 0              NaN  2024-09-23 15:27:17.455269
# 1              NaN  2024-09-23 15:27:28.813171
# 2              NaN  2024-09-23 15:27:39.131279
# 3              NaN  2024-09-23 15:27:51.620380
# 4              NaN  2024-09-23 15:28:12.225006

# %% [markdown]
# ## Extract body only

# %%
def extractElement(html_text: str, html_element: str) -> str:
    """
    Extract a defined element of HTML elements including the tags using BS4

        params:
            html_text (str): html text
            html_element (str): element to extract from `html_text`
        return:
            body elements as string
    """

    return str(BeautifulSoup(html_text, "lxml").find(html_element))

# %%
df_clean["extracted_body"] = df_clean["scraped_elements"].apply(extractElement, html_element="body")

# %%
df_clean.loc[0, "extracted_body"]
# Out:
# '<body class="no-js"><div class="main-wrapper" role="main"><div class="main-content"><h1 class="zone-name-title h1">www.nikosgreekrestaurant.com</h1><h2 class="h2 spacer-bottom" id="AnPU2">Verify you are human by completing the action below.</h2><div id="JStsl2" style="display: grid;"><div><div><input id="cf-chl-widget-xy0lv_response" name="cf-turnstile-response" type="hidden"/></div></div></div><div class="spacer loading-spinner" id="Psjc8" style="display: none; visibility: hidden;"><div class="lds-ring"><div></div><div></div><div></div><div></div></div></div><div class="core-msg spacer spacer-top" id="UJXr0">www.nikosgreekrestaurant.com needs to review the security of your connection before proceeding.</div><div id="BQxuW7" style="display: none;"><div class="h2" id="challenge-success-text">Verification successful</div><div class="core-msg spacer">Waiting for www.nikosgreekrestaurant.com to respond...</div></div><noscript><div class="h2"><span id="challenge-error-text">Enable JavaScript and cookies to continue</span></div></noscript></div></div><script>(function(){window._cf_chl_opt={cvId: \'3\',cZone: "www.nikosgreekrestaurant.com",cType: \'managed\',cNounce: \'9690\',cRay: \'8c792759f9859c53\',cHash: \'d8c56896924cf7f\',cUPMDTk: "\\/?__cf_chl_tk=H7r4EQZi5FiUIbc128rsa9DnLyl1dOFW3AqdllW75Fg-1727080027-0.0.1.1-4884",cFPWv: \'g\',cTTimeMs: \'1000\',cMTimeMs: \'390000\',cTplV: 5,cTplB: \'cf\',cK: "",fa: "\\/?__cf_chl_f_tk=H7r4EQZi5FiUIbc128rsa9DnLyl1dOFW3AqdllW75Fg-1727080027-0.0.1.1-4884",md: "wEoukU239iMAgqq1bOyByrJUoa72gS0o232G5kCukp8-1727080027-1.1.1.1-Pt7D_qyI802iZSnekn8fWbnlo9KEbd1iL.9N5HfD4rbJVMfo8qW25VkTl4nAwy7rfkJIdhywS8unfgpiQFNU605QxqW0kO.LwOVeL3eJfZRu8DlIt1GpYgET._D71FDRHOUyIKaOx5dm28TbZBLI7MDU7Ms21YaoAKRzJuirjNdnM2ah8dTAX7ANGcpAF3ASTIm7nHK2UDmZ5NldbRZ45qMBqMoJW0o2u3wOb9MQrq4JJzkt8hlMq.N1b4tkNiSsiFDphVpzSrCLhuD3wjt52mFvCCOusQP1aLmflgUeT9KidS.dHT04gytqCUD0SJmUD7t99gxOw9l.N7lT4XhreJ6_ZhZcfoVrz_Aq4KalAPjOtFGuwDXTzqVHtsg6PjHtsfK2dhQxEPlA6Q8ONIS18L4HuQJV0DiI4
t1BdPsQK3uc0eMflUpUZc184TVrA5HDrwxluxVbgxKhncjXAFsA26vaWMie_mJXrsUlEVY1yVInElOk47XdKFI9bXIyMJk9ySv1Vw0G0FwUZTN8.La_Y0Son6mR9BTKhdRkdox4.4C.0X5n8dhVlvgnsehq36QldsI6FnnMU_qFfpzU3LdOEB_VUY1AGOKflat5xcL3jLhHAH2Ln3eefRsADIYZZRU6bFDPRnxPer9UaMKzVdeZCVE2bzrKKLo9j7ylTeDliCaCzSzXZWOD3gHZHoYNkiKjUBpSPeIerZVIJAXUvZOd8OjHxgxSWtwuHH4ZRgKA8",mdrd:  ...

# %% [markdown]
# ## Filter Importants Columns

# %%
df_clean = df_clean[["extracted_body", "is_gambling_site"]]

# %% [markdown]
# ## Row Filtering

# %% [markdown]
# ### Remove data points that blocked by Cloudflare

# %%
df_clean.loc[df_clean["extracted_body"].str.contains('cloudflare.com', case=False)]
# Out:
#                                        extracted_body  is_gambling_site
# 0   <body class="no-js"><div class="main-wrapper" ...                 1
# 2   <body>\n<div id="cf-wrapper">\n<div class="cf-...                 1
# 7   <body class="no-js"><div class="main-wrapper" ...                 1
# 15  <body class="no-js"><div class="main-wrapper" ...                 1
# 20  <body>\n<div id="cf-wrapper">\n<div class="cf-...                 1
# 49  <body class="articles show category-bisnis imm...                 0
# 53  <body class="no-js"><div class="main-wrapper" ...                 0
# 61  <body class="no-js"><div class="main-wrapper" ...                 0

# %%
df_clean = df_clean.drop(
    index = df_clean.loc[df_clean["extracted_body"].str.contains('cloudflare.com', case=False)].index
)

# %%
df_clean.head()
# Out:
#                                       extracted_body  is_gambling_site
# 1  <body>\n<main>\n<div class="mputama">\n<img al...                 1
# 3  <body class="amp-dark-mode amp-mode-mouse" sty...                 1
# 4  <body data-spm="pdp_revamp" style="overflow-y:...                 1
# 5  <body>\n<main>\n<div class="mputama">\n<img al...                 1
# 6  <body class="modal-open" style="--expand-icon-...                 1

# %% [markdown]
# ## Text Cleaning

# %%
def removeScriptContents(text: str) ->str:
    """
    Replace scripts tags and the contents

        param:
            text (str): text to clean
        return:
            new text without scripts tags and contents
    """
    return re.sub("<script>.*?<\/script>", " ", text)

def removeHTMLTag(text: str) -> str:
    """
    Remove HTML tags from the text

    -------------
    Ex:
    -------------
    <body>
    lorem ipsum
    dolor sit amet
    </body>

    -------------
    Return:
    -------------
    lorem ipsum
    dolor sit amet

        param:
            text (str): text to clean
        return:
            new text without HTML tags
    """
    
    return re.sub("<.*?>" , "", text)

def removeNewLine(text: str) -> str:
    """
    Remove new line's escape chars (\n) from the text

        param:
            text (str): text to clean
        return:
            new text without \n
    """

    return text.replace("\n", "")

def removeContentsInsideCurlyBrackets(text: str) -> str:
    """
    Clean text by removing curly brackets and any contents within them
    
    -------------
    Ex:
    -------------
    {
        "vars": {
            "gtag_id": "UA-241896104-1",
            ...
        }
    }

    <body>
        ....
    </body>

    -------------
    Return:
    -------------
    <body>
        ....
    </body>

        params:
            text (str): text to clean
        return:
            new text without curly brackets and any contents whithin them
    """

    return re.sub("{.*}", "", text)

def removeAllExceptAlphabetPeriod(text: str) -> str:
    """
    Replace all characters except alphabets and period [a-zA-Z.] with whitespace

        param:
            text (str): text to clean
        return:
            new text contains alphabets and periods
    """

    return re.sub("[^a-zA-Z.]+", " ", text)

def removeWhiteSpacesBeforeAfterPeriod(text: str) -> str:
    """
    Remove whitespaces before and after the period, but the period char preserved

    -------------
    Ex:
    -------------
    foo . buzz
    buzz. foo

    -------------
    Return:
    -------------
    foo.buzz
    buzz.foo

        param:
            text (str): text to clean
        return:
            new text that doesn't contain any whitespaces before and after period
    """

    return re.sub("\s+(?=\.)|(?<=\.)\s+", "", text)

def removeJqueryFunctionSelector(text: str) -> str:
    """
    Replace jquery function and selector strings inside the text with a whitespeace using regex.
    The regex will match string started with word function until it meets a semicolon (;)

    -------------
    Ex:
    -------------
    function foo(buzz) buzz.lower();' Lorem ipsum
    $(bazz).window{lorem ipsum};' dolor sit amet

    -------------
    Return:
    -------------
    ' Lorem ipsum
    ' dolor sit amet
    """

    return re.sub("(function|\$).*[;]+", " ", text)

def removeURL(text: str) -> str:
    """
    Replace all urls with whitespace

        param:
            text (str): text to clean
        return:
            new text without any urls
    """

    return re.sub("(www|http|https)\S*", " ", text)

def removeRepeatingWhitespace(text: str) -> str:
    """
    Replace repeating whitespaces (at least 2) with a whitespace

        param:
            text (str): text to clean
        return:
            new text without repeating whitespaces
    """

    return re.sub("\s{2,}", " ", text)

def textToLower(text: str) -> str:
    """
    Convert all characters to lowercase
    
        param:
            text (str): text to transform into lowercase
        return:
            transformed text to lowercase
    """

    return text.lower()

def stripText(text: str) -> str:
    """
    Remove leading and trailing whitespaces in the text

        param:
            text (str): text to clean
        return:
            cleaned text
    """

    return text.strip()

def removeTechnicalWords(text: str) -> str:
    """
    Remove technical words that don't represent the charactheristics of both gambling and non-gambling sites
    
    Technical word list:
        - https
        - http
        - www
        - true
        - integrity
        - login
        - window
        - cmd
        - svg
        - config
        - style
        - loader
        - network
        - pixel
        - css
        - loading
        - script

    -------------
    Ex:
    -------------
    Indonesiaurlhttpsthedinerqccomproductssamsungtinchd lorem ipsum
    cfExtPritruecfLtrueversiontokenaacaaaafeb dolor sit amet

    -------------
    Return:
    -------------
    lorem ipsum
    dolor sit amet

        param:
            text (str): text to clean
        return:
            new text after removing technical words
    """
    return re.sub("\S*(https|http|www|true|integrity|login|window|cmd|svg|config|style|loader|network|pixel|css|script|loading)\S*", "", text)

def addPeriodAtEndofText(text: Union[str, None]) -> Union[str, None]:
    """
    Add period sign (if there isn't any) at the end of text to indicate the sentence is ended
    Skip the process if the text is None
    
	-------------
    Ex:
    -------------
    Commodo excepteur elit consequat ullamco.
    Culpa officia nulla Lorem mollit enim veniam cillum
    None

    -------------
    Return:
    -------------
    Commodo excepteur elit consequat ullamco.
    Culpa officia nulla Lorem mollit enim veniam cillum.
    None
    
		param:
			text (str): text to clean
		return:
			new text that has period at the end of it
    """
    
    if text == None:
        return None
    elif text[-1] == ".":
        return text
    
    return text+"."

def castEmptyTextToNone(text: str) -> Union[str, None]:
    """
    Return None if the text is an empty string, otherwise return itself
    
		param:
			text (str): text to be casted
		return:
			str if not None, otherwise None
    """
    
    return None if text == "" else text

def preprocessTextPipeline(text: Union[str, None]) -> Union[str, None]:
    """
    Clean the text by appling text cleaning pipeline
    Skip the process if the text is None

        param:
            text (str): text to clean
        return:
            cleaned text
    """
    
    if text == None:
        return None

    cleaned_text = textToLower(text)
    cleaned_text = removeNewLine(cleaned_text)
    cleaned_text = removeScriptContents(cleaned_text)
    cleaned_text = removeHTMLTag(cleaned_text)
    cleaned_text = removeJqueryFunctionSelector(cleaned_text)
    cleaned_text = removeURL(cleaned_text)
    cleaned_text = removeContentsInsideCurlyBrackets(cleaned_text)
    cleaned_text = removeAllExceptAlphabetPeriod(cleaned_text)
    cleaned_text = removeTechnicalWords(cleaned_text)
    cleaned_text = removeRepeatingWhitespace(cleaned_text)
    cleaned_text = removeWhiteSpacesBeforeAfterPeriod(cleaned_text)
    cleaned_text = stripText(cleaned_text)
    cleaned_text = castEmptyTextToNone(cleaned_text)
    cleaned_text = addPeriodAtEndofText(cleaned_text)

    return cleaned_text

# %% [markdown]
# ### Extract Name Property Value

# %%
def extractNamePropertyValues(text: str) -> Union[str, None]:
    """
    Extract `"name"` properties from the text, then concate them into a sentence

        param:
            text (str): text to clean
        return:
            name properties formed into a sentence
    """

    name_prop_vals = re.findall("(?<=\"name\":)\"[^\"]*\"", text)

    for idx, name_val in enumerate(name_prop_vals):
        # remove all chars except a-zA-Z and whitespace
        str_val = re.sub("[^a-zA-Z ]+", "", name_val).strip()
        name_prop_vals[idx] = str_val

    combined_vals = " ".join(name_prop_vals)

    # return None if there's no value in combined_vals 
    # or the combined name property values are below 10 characters
    if(combined_vals == ""
        or len(combined_vals) <= 10):
        return None

# %%
df_clean["extracted_name_vals"] = df_clean["extracted_body"].apply(extractNamePropertyValues)
df_clean["extracted_name_vals"] = df_clean["extracted_name_vals"].apply(preprocessTextPipeline)

# %%
df_clean.head()
# Out:
#                                       extracted_body  is_gambling_site  \
# 1  <body>\n<main>\n<div class="mputama">\n<img al...                 1
# 3  <body class="amp-dark-mode amp-mode-mouse" sty...                 1
# 4  <body data-spm="pdp_revamp" style="overflow-y:...                 1
# 5  <body>\n<main>\n<div class="mputama">\n<img al...                 1
# 6  <body class="modal-open" style="--expand-icon-...                 1
#
#   extracted_name_vals
# 1                None
# 3                None
# 4                None
# 5                None
# 6                None

# %% [markdown]
# ### Extract Other Values from Body

# %%
df_clean["extracted_body"] = df_clean["extracted_body"].apply(preprocessTextPipeline)

# %%
df_clean.loc[4, "extracted_name_vals"]

# %% [markdown]
# # Split Text from Extracted Body by .

# %% [markdown]
# - In this section, I will split the text from cleaned text from extracted_body by . to get sentences
# - Then I will create new dataframe where each row will contain a sentence
# - The text from extacted_name_vals will also be added to the new dataframe

# %%
splitted_texts = []

for _, row in df_clean[["extracted_body", "is_gambling_site"]].iterrows():
    if row["extracted_body"] == None:
        continue
    
    split_texts = row["extracted_body"].split(".")
    for text in split_texts:
        splitted_texts.append([text, row["is_gambling_site"]])

for _, row in df_clean[["extracted_body", "is_gambling_site"]].iterrows():
    if row["extracted_body"] == None:
        continue
        
    splitted_texts.append([row["extracted_body"], row["is_gambling_site"]])

# %%
splitted_texts
# Out:
# [['daftarmasuk hot games slots casino sports arcade poker togel live tv usd',
#   1],
#  ['pemberitahuan pemeliharaan terjadwal sbo virtual sports pada dari am sampai pm gmt',
#   1],
#  ['selama waktu ini sbo virtual sports permainan tidak akan tersedia', 1],
#  ['kami memohon maaf atas ketidaknyamanan yang mungkin ditimbulkan', 1],
#  ['pemeliharaan terjadwal ion slot pada dari am sampai pm gmt', 1],
#  ['selama waktu ini ion slot permainan tidak akan tersedia', 1],
#  ['kami memohon maaf atas ketidaknyamanan yang mungkin ditimbulkan', 1],
#  ['pemeliharaan terjadwal balak d pada dari am sampai am gmt', 1],
#  ['selama waktu ini balak d permainan tidak akan tersedia', 1],
#  ['kami memohon maaf atas ketidaknyamanan yang mungkin ditimbulkan', 1],
#  ['selamat datang di situs super situs judi online slot terlengkap pemeliharaan terjadwal sbo virtual sports pada dari am sampai pm gmt',
#   1],
#  ['selama waktu ini sbo virtual sports permainan tidak akan tersedia', 1],
#  ['kami memohon maaf atas ketidaknyamanan yang mungkin ditimbulkan', 1],
#  ['pemeliharaan terjadwal ion slot pada dari am sampai pm gmt', 1],
#  ['selama waktu ini ion slot permainan tidak akan tersedia', 1],
#  ['kami memohon maaf atas ketidaknyamanan yang mungkin ditimbulkan', 1],
#  ['pemeliharaan terjadwal balak d pada dari am sampai am gmt', 1],
#  ['selama waktu ini balak d permainan tidak akan tersedia', 1],
#  ['kami memohon maaf atas ketidaknyamanan yang mungkin ditimbulkan', 1],
#  ['selamat datang di situs super situs judi online slot terlengkap sel gmt usd',
#   1],
#  ['video slots popular pemenang mesin slot rickygu nidr', 1],
#  ['john hunter and the book of tut d yidr', 1],
#  ['sweet bonanza cobamaindragon tiger cobamainbronco spirit cobamainaztec gems deluxe cobamainhot to burn cobamaintriple joker cobamain lions gold unduh aplikasi gratis nexus mobilenikmati berbagai permainan dalam satu gengamanandroid apkversi terakhir mbpanduan instalasipindai kode qr untuk unduh apkunduh apknikmati berbagai permainan dalam satu gengamanunduhpanduan instalasi panduan instalasi instalasi android pindai kode qr untuk android pilih buka situs web pilih unduh untuk mengunduh apk kami pilih pengaturan pilih mengizinkan dari sumber kami pilih terima pilih instal home slot online super situs judi slot online gacor hari ini paling terpercaya amp resmi indonesialast updated september super situs judi slot online gacor hari ini paling terpercaya amp resmi indonesia tidak bisa dipungkiri saat ini dengan semakin membesarnya game slot online semakin banyak situs judi slot baru bermunculan',
#   1],
#  ['namun kebanyakan situs situs ini justru membuat pemainnya rugi', 1],
#  ['kebanyakan member situs judi online abal abal yang termakan oleh janji manis belaka misalnya saja mengatakan jika game slot di situs mereka adalah game slot gacor semua atau game slot gacor mereka memiliki jackpot terbesar padahal rahasia bisa cuan main slot online paling utama adalah pilihan situs judi online',
#   1],
#  ['tenang saja hal itu tidak perlu lagi anda khawatirkan kalau sudah bermain di super situs judi online tergacor dan terpercaya',
#   1],
#  ['dengan terbiasa bermain dalam atmosfir dan simbol yang terpampang dalam roll slot online pemain jadi bisa lebih jeli dalam menentukan arahan jackpot yang akan keluar nantinya',
#   1],
#  ['bonus slot new member yang bejibunkami memiliki segudang bonus untuk member yang sudah join di tahun ini',
#   1],
#  ['berikut paparannya bonus new member jutabonus member get member', 1],
#  ['bonus depo pertama sportbookkomisi harian', 1],
#  ['bonus mingguan promo win loss bonus sportsbookbonus mingguan bonus deposit slot online perdana partner ternama super super merupakan situs judi slot online yang tergabung dalam aliansi resmi pragmatic yang disebut dengan pragmatic group indonesia',
#   1],
#  ['pragmatic sendiri merupakan salah satu situs judi slot gacor terbesar di indonesia dengan jumlah pemain hinggal puluhan juta pemain',
#   1],
#  ['berikut adalah daftar partner super yang tergabung dalam pragmatic group indonesia pragmatic pragmaticidkripto king pragmatic cara membuat akun amp depo di super nah tertarik gabung kan setelah tau keunggulan main di super yuk rasakan kegacoran beragam permainan slot terbaik dengan kualitas yang tidak diragukan lagi',
#   1],
#  ['cek info di bawah ini untuk mulai perjalanan kamu mendapatkan jackpot maxwin hingga ribuan kali',
#   1],
#  ['cara buat akun super jangan takut bermain di super karena merupakan situs judi slot terpercaya dan partner resmi dari pragmatic play microgaming serta penyedia game slot lainnya di indonesia',
#   1],
#  ['untuk membuat akun caranya sangat mudah dan cepat anda cukup ikuti langkah di bawah ini klik button daftar di situs judi terpercaya super isi informasi pribadi dan rekening bank dengan benar',
#   1],
#  ['jangan lupa masukkan kode referensi teman jika ada', 1],
#  ['isi kotak verifikasi', 1],
#  ['putar ulang kode jika salah', 1],
#  ['pastikan semua data sudah sesuai baru klik button daftar', 1],
#  ['cara depositmetode deposit yang tersedia adalah transfer bank e money dan pulsa',
#   1],
#  ['untuk deposit pertama kali member harus menambah akun bank terlebih dahulu',
#   1],
#  ['deposit via transfer bankisi jumlah yang ingin ditransfer dalam ribuan', 1],
#  ['misal ingin depo rb maka yang diisi adalah', 1],
#  ['perhatikan nomor rekening tujuan yang tercantum dan pastikan mentransfer ke nomor tersebut',
#   1],
#  ['deposit dengan e money ovo dana gopay linkaja tambahkan dahulu akun e money anda sebelum mengisi form depo',
#   1],
#  ['di formulir depo pilih metode e money', 1],
#  ['pilih nominal dan sumber dana yang diinginkan', 1],
#  ['anda akan diarahkan ke layar penyelesaian pembayaran menggunakan qris', 1],
#  ['pilih kembali opsi qris untuk melanjutkan', 1],
#  ['kode qris akan muncul di layar anda', 1],
#  ['scan dengan aplikasi pembayaran yang diinginkan misal ovo', 1],
#  ['lanjutkan membayar di aplikasi ovo anda dengan meng scan kode qris', 1],
#  ['setelah selesai lihat kembali halaman qris di website dan klik button cek status pembayaran',
#   1],
#  ['anda akan diarahkan kembali ke situs permainan setelah topup berhasil', 1],
#  ['tips dan trik main slot anti rungkad di super bagi pemain yang masih belum lama memulai di dunia slot online pasti masih memiliki ketakutan kalah dalam bermain dan kehilangan uang',
#   1],
#  ['namun anda tidak perlu khawatir karena tim super tidak takut berbagi tips dan trik supaya anda sekalian bisa terus enjoy main bersama super',
#   1],
#  ['berikut ini beberapa tipsnya latihan dengan daftar demo slot onlinedengan memanfaatkan fitur demo slot online teman teman bisa mengasah keterampilan teman teman dalam menentukan jumlah nominal yang dipertaruhkan dan menentukan momen di mana jackpot bisa terjadi',
#   1],
#  ['salah satunya yang bisa dicoba di super adalah demo slot pragmatic', 1],
#  ['practice makes perfect bijak dalam menentukan jumlah pertaruhandalam slot online kuantitas roll dalam bermain menentukan jumlah kemenangan pemain secara lebih merata dan lebih terjamin',
#   1],
#  ['untuk itu perhitungkan matang matang langkah yang ingin kalian tempuh dalam bermain di salah satu game slot gacor super',
#   1],
#  ['mengamati waktu bermain jam gacorjam gacor adalah sebuah istilah di mana ada pada kalanya situs judi online memberikan kesempatan bagi pemain untuk memperoleh lebih sering jp slot dan jackpot maxwin slot online dalam kurun waktu tertentu',
#   1],
#  ['di super jam slot gacor akan lebih sering dan berdurasi lama pada malam hari dan di weekend tentunya',
#   1],
#  ['cari tahu pola slot gacorsetiap permainan slot memiliki pola gacor yang berbeda',
#   1],
#  ['ada baiknya sebelum mulai bermain cari tahu lebih dulu tentang info slot gacor hari ini sehingga dapat menyesuaikan dengan permainan anda',
#   1],
#  ['pusat bantuansyarat dan ketentuanresponsible gamingtentang super copyright super agen slot pragmatic slot pg soft microgaming terbaik aman dan terpercaya',
#   1],
#  ['ikuti kamiberanda daftar promosi live chat', 1],
#  ['', 1],
#  ['live chat unduh apk versi mobile englishenglishbhs indonesiaindonesian korean chinese japanese thai burmese khmer hindi tamil teluguti ng vi tvietnamese bengaliportugu sportugese lupa kata sandi daftar hot games slots live casino togel olahraga crash game arcade poker e sports sabung ayam promosi pemberitahuan pemeliharaan terjadwal mg live pada dari am sampai pm gmt',
#   1],
#  ['selama waktu ini mg live permainan tidak akan tersedia', 1],
#  ['kami memohon maaf atas ketidaknyamanan yang mungkin ditimbulkan', 1],
#  ['pemeliharaan terjadwal crowd play pada dari am sampai pm gmt', 1],
#  ['selama waktu ini crowd play permainan tidak akan tersedia', 1],
#  ['kami memohon maaf atas ketidaknyamanan yang mungkin ditimbulkan', 1],
#  ['pemeliharaan terjadwal esports bull pada dari am sampai am gmt', 1],
#  ['selama waktu ini esports bull permainan tidak akan tersedia', 1],
#  ['kami memohon maaf atas ketidaknyamanan yang mungkin ditimbulkan', 1],
#  ['pemeliharaan terjadwal mg live pada dari am sampai pm gmt', 1],
#  ['selama waktu ini mg live permainan tidak akan tersedia', 1],
#  ['kami memohon maaf atas ketidaknyamanan yang mungkin ditimbulkan', 1],
#  ['pemeliharaan terjadwal crowd play pada dari am sampai pm gmt', 1],
#  ['selama waktu ini crowd play permainan tidak akan tersedia', 1],
#  ['kami memohon maaf atas ketidaknyamanan yang mungkin ditimbulkan', 1],
#  ['pemeliharaan terjadwal esports bull pada dari am sampai am gmt', 1],
#  ['selama waktu ini esports bull permainan tidak akan tersedia', 1],
#  ['kami memohon maaf atas ketidaknyamanan yang mungkin ditimbulkan', 1],
#  ['sen', 1],
#  ['gmt idr game populer main gates of olympus main mahjong ways main mahjong wins main jajanan pasar main le pharaoh main starlight princess main sixsixsix main way of ninja main starlight princess main mahjong ways main nexus gates of olympus main wild bounty showdown main lucky twins nexus main nexus koi gate main the crypt main lucky twins power clusters main mental main fortune gems main hot hot nexus main fortune gems video slots popular pemenang mesin slot kurni idr',
#   1],
#  ['pyramid bonanzama idr', 1],
#  ['gates of olympus ky idr', 1],
#  ['starlight princess p t idr', 1],
#  ['gates of olympus go i idr', 1],
#  ['starlight princess gogongi idr', 1],
#  ['gates of olympus gogongi idr', 1],
#  ['gates of olympus go i idr', 1],
#  ['starlight princess h n idr', 1],
#  ['gates of olympus gogongi idr', 1],
#  ['gates of olympus coba main coba main coba main coba main coba main coba main main main main main main main main main main main main main coba main coba main coba main coba main coba main coba main coba main coba main coba main coba main coba main coba main main main main main main main coba main coba main coba main coba main coba main coba main main main main main main main coba main coba main coba main coba main coba main coba main coba main coba main coba main coba main coba main coba main main main main main main main coba main coba main coba main coba main coba main coba main coba main coba main coba main coba main coba main coba main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main unduh aplikasi gratis texas appnikmati berbagai permainan dalam satu genggamantexas apppanduan instalasipindai kode qr untuk unduh android apk panduan instalasi instalasi android pindai kode qr untuk android pilih buka situs web pilih unduh untuk mengunduh texas app pilih pengaturan pilih mengizinkan dari sumber kami pilih terima pilih instal tentang texas responsible gamblingsyarat dan ketentuanpusat bantuan texas',
#   1],
#  ['hak cipta dilindungi slot gacor hari ini texas paling meledak terpercaya amp terbaik texas merupakan situs slot gacor hari ini yang sudah dipercaya banyak orang di indonesia',
#   1],
#  ['terpilih sebagai situs judi slot paling bonafit dan gampang meledak dengan pelayanan terbaik dijamu bagaikan selir selir yang melayani raja di kayangan',
#   1],
#  ['terdapat banyak pilihan game slot gacor dengan info yang diberikan oleh para customer service winrate terbaik yang dapat anda mainkan',
#   1],
#  ['sehingga anda mendapatkan sensasi kemenangan yang luar biasa di situs slot gacor yang kami sediakan sekarang selalu dan selamanya pilihan koko aseng dan aciang',
#   1],
#  ['kami memiliki berbagai sistem teknologi dengan performa gaming yang sangat memanjakan para bettor bermain judi slot layaknya bermain di casino sungguhan',
#   1],
#  ['pelayanan kami yang prima dan siap sigap selama jam non stop melayani anda dengan ramah akan memberikan kesan tersendiri',
#   1],
#  ['kami juga sudah teraffliasi dengan berbagai pihak yang berhubungan dengan pihak bertanggung jawab dalam perjudian daring di seluruh asia karena ini tidak perlu kwatir dengan kualitas keamanan data proses deposit dan withdraw di texas',
#   1],
#  ['kami merupakan situs slot gacor terbaik di indonesia', 1],
#  ['slot gacor apa sih artinya slot gacor adalah sebutan untuk game slot online yang sedang memberikan kemenangan terus menerus kepastian mendapatkan kemenangan jackpot',
#   1],
#  ['slot gacor sering menjadi incaran setiap pemain yang sedang bermain judi slot untuk mendapatkan maxwin sampai mentok',
#   1],
#  ['apa itu situs slot gacor amp bagaimana cara mencari situs paling gacor situs slot gacor dapat dicari dengan mencari di google list situs judi slot yang terdapat di dalamnya untuk menguji kegacoran suatu situs adalah dengan cara mencoba bermain dengan deposit tipis tipis dan lihat probabilitas tingkat kemenangan lebih ada di situs yang mana',
#  ['jenis permainan sbobet paling populersbobet selalu berkomitmen untuk memberikan permainan yang seru kepada publik',
#   1],
#  ['banyak jenis permainan populer di dalam situs sbobet yang bisa anda mainkan',
#   1],
#  ['antara lain taruhan bola sportsbookuntuk permainan sportbook sendiri terdapat beberapa pilihan yang bisa anda mainkan seperti judi bola live bola virtual basket tenis meja e sport es hoki voli golf badminton balap sepeda tinju moto gp dan semua taruhan olahraga bisa anda mainkan',
#   1],
#  ['live casinojudi live casino pertama kali bergabung bersama sbobet pada tahun',
#   1],
#  ['ini merupakan terobosan yang sangat baik karena kita ketahui peminat casino sangat besar',
#   1],
#  ['dulu jika kita ingin bermain roulette dadu game kartu dan mesin slot kita harus ke negara lain itu akan memakan biaya dan waktu',
#   1],
#  ['namun untuk sekarang kita tidak lagi susah payah jika ingin bermain karena bisa main game casino dirumah menggunakan handphone dan jaringan internet',
#   1],
#  ['live casino ini bisa anda saksikan langsung secara real anda semua akan merasa berada di dalam kasino sangat melakukan taruhan',
#   1],
#  ['maka dari tidak bisa dipungkiri bahwa live casino sangat banyak orang cari di google',
#   1],
#  ['salah satu keunggulan bermain live casino adalah anda bisa langsung melakukan deposit dan penarikan dana dengan cepat tidak harus menunggu antrian lagi',
#   1],
#  ['slot onlineuntuk saat ini jika bicara tentang slot online pasti sudah tau bukan ya slot online saat ini sangat populer di indonesia',
#   1],
#  ['hampir semua kalangan main game slot tersebut karena permainan tersebut sangat mudah sekali dimainkan dan gampang mendapatkan kemenangan',
#   1],
#  ['di sbobet sendiri sudah ada permainan slot online semua jenis permainan dan provider slot online telah bergabung dengan server sbobet',
#   1],
#  ['anda bisa memainkan semua game slot tanpa ada lag sedikitpun', 1],
#  ['permainan kenopermainan keno hampir mirip dengan permainan togel atau dadu',
#   1],
#  ['terdapat nomor akan diajak dan anda hanya cukup menebak angka yang akan keluar',
#   1],
#  ['pilih angka dari tersebut jika tebakan anda benar maka akan mendapatkan hadiah yang lumayan besar',
#   1],
#  ['permainan keno banyak dimainkan oleh kalangan lebih dewasa dikarenakan game tersebut harus memiliki insting yang kuat dan strategi',
#   1],
#  ['di dalam situs sbobet terbagi macam jenis keno yaitu keno atom rng war dan number game',
#   1],
#  ['horse racing balapan kudabalapan kuda merupakan permainan internasional yang diresmikan di beberapa negara',
#   1],
#  ['sbobet bekerja sama dengan negara britania raya dan irlandia untuk mengadakan balap kuda live',
#   1],
#  ['jadi saat pertandingan pacuan kuda dilakukan maka negara lain juga bisa melakukan taruhan secara live',
#   1],
#  ['game horse racing ini memiliki hadiah yang sangat besar sekali dan cara bermain balap kuda anda hanya memilih kuda favorit anda menang',
#   1],
#  ['cara daftar akun sbobet di situs link resmi sbobet sebelum sbobet untuk melakukan taruhan bola anda harus melakukan daftar sbobet terlebih dahulu',
#   1],
#  ['untuk cara daftar akun sbobet juga sangat mudah sekali hanya butuh waktu sekitar menit saja',
#   1],
#  ['cara daftar akun sbobet pertama yang dilakukan adalah siapkan data rekening valid yang akan digunakan untuk daftar akun sbobet setelah itu buka link resmi sbobet yaitu pafipayakumbuh',
#   1],
#  ['kami memohon maaf atas ketidaknyamanan yang mungkin ditimbulkan', 1],
#  ['pemeliharaan terjadwal crowd play pada dari am sampai pm gmt', 1],
#  ['selama waktu ini crowd play permainan tidak akan tersedia', 1],
#  ['kami memohon maaf atas ketidaknyamanan yang mungkin ditimbulkan', 1],
#  ['pemeliharaan terjadwal esports bull pada dari am sampai pm gmt', 1],
#  ['selama waktu ini esports bull permainan tidak akan tersedia', 1],
#  ['kami memohon maaf atas ketidaknyamanan yang mungkin ditimbulkan', 1],
#  ['pemeliharaan terjadwal mg live pada dari am sampai pm gmt', 1],
#  ['selama waktu ini mg live permainan tidak akan tersedia', 1],
#  ['kami memohon maaf atas ketidaknyamanan yang mungkin ditimbulkan', 1],
#  ['pemeliharaan terjadwal crowd play pada dari am sampai pm gmt', 1],
#  ['selama waktu ini crowd play permainan tidak akan tersedia', 1],
#  ['kami memohon maaf atas ketidaknyamanan yang mungkin ditimbulkan', 1],
#  ['pemeliharaan terjadwal esports bull pada dari am sampai pm gmt', 1],
#  ['selama waktu ini esports bull permainan tidak akan tersedia', 1],
#  ['kami memohon maaf atas ketidaknyamanan yang mungkin ditimbulkan', 1],
#  ['sen', 1],
#  ['gmt idr singapore d live draw sun am game populer main gates of olympus main mahjong ways main mahjong wins main jajanan pasar main le pharaoh main starlight princess main sixsixsix main way of ninja main starlight princess main mahjong ways main nexus gates of olympus main wild bounty showdown main lucky twins nexus main nexus koi gate main the crypt main lucky twins power clusters main mental main fortune gems main hot hot nexus main fortune gems video slots popular pemenang mesin slot oc idr',
#   1],
#  ['nexus sugar rushoc idr', 1],
#  ['nexus sugar rushpan idr', 1],
#  ['gates of olympus oc idr', 1],
#  ['nexus sugar rushc o idr', 1],
#  ['starlight princess o a idr', 1],
#  ['starlight princess kevi idr', 1],
#  ['sweet bonanza ji idr', 1],
#  ['gates of olympus pan idr', 1],
#  ['gates of olympus moko idr', 1],
#  ['slot olympus coba main coba main coba main coba main coba main coba main main main main main main main main main main main main main coba main coba main coba main coba main coba main coba main coba main coba main coba main coba main coba main coba main main main main main main main coba main coba main coba main coba main coba main coba main main main main main main main coba main coba main coba main coba main coba main coba main coba main coba main coba main coba main coba main coba main main main main main main main coba main coba main coba main coba main coba main coba main coba main coba main coba main coba main coba main coba main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main main unduh aplikasi gratis oceanslot appnikmati berbagai permainan dalam satu genggamanoceanslot apppanduan instalasipindai kode qr untuk unduh android apk panduan instalasi instalasi android pindai kode qr untuk android pilih buka situs web pilih unduh untuk mengunduh oceanslot app pilih pengaturan pilih mengizinkan dari sumber kami pilih terima pilih instal tentang oceanslot responsible gamblingpusat bantuansyarat dan ketentuan oceanslot',
#   1],
#  ['hak cipta dilindungi oceanslot situs judi slot online gacor hari ini slot indonesiajaminan pasti bayar bonus jackpot maxwin adalah hal yang sangat penting ketika kamu bermain judi slot online gacor di situs slot indonesia',
#   1],
#  ['permainan judi slot online yang kami tawarkan kepada anda di situs oceanslot adalah yang terbaik dan tentu saja mudah pecah jackpot',
#   1],
#  ['segera depositkan modal permainan anda di situs terpercaya milik kami dan rasakan sendiri sensasi memenangkan jackpot dari judi slot online gacor mencapai puluhan juta rupiah',
#   1],
#  ['oceanslot merupakan situs slot indonesia yang telah mendapat predikat sebagai situs judi slot online gacor hari ini paling lengkap',
#   1],
#  ['setiap hari nya ribuan member setia kami selalu mengakses situs slot gacor oceanslot untuk mencari keuntungan yang konsisten secara cepat',
#   1],
#  ['tidak ada yang lebih membahagiakan ketika kami oceanslot dapat menjadi bagian dari kesuksesan anda meraih kemenangan besar lewat slot online gacor hari ini',
#   1],
#  ['mendapatkan keuntungan secara cepat di judi slot online gacor akan membuat hidup anda berubah secara drastis',
#   1],
#  ['bagi anda sekalian yang sedang mencari pengalaman bermain slot paling seru dan mempunyai jackpot besar maka situs judi slot online gacor hari ini oceanslot adalah pilihan tepat',
#   1],
#  ['segera masuki dan jelajahi sendiri dunia judi slot online yang berbeda hanya melalui situs slot indonesia di link oceanslot',
#   1],
#  ['pelayanan keunggulan pelayanan deposit rata rata waktu min penarikan rata rata waktu min produk keunggulan produk taruhan slot penyedia slot online dengan beragam pilihan game menarik yang memudahkan pemain untuk mencapai jackpot taruhan togel platform togel yang menarik dari perusahan terbaik di dunia yang menawarkan hadiah kemenangan besar taruhan live kasino platform pilihan bagi perusahaan perusahaan terbaik di dunia dengan pilihan variasi game terbanyak taruhan olahraga sportsbook gaming platform terbaik menawarkan lebih banyak game odds yang lebih tinggi dan menyediakan pilihan yang lebih banyak untuk pemain',
#   1],
#  ['bantuan amp dukungan servis lainnya oceanslot terhubung dengan kami bersertifikasi dari tanggung jawab bermain browser yang didukung platform penyedia layanan slots live casino togel olahraga crash game arcade e sports sabung ayam qris autodepo ok batal ok domcontentloaded',
#   1],
#  ['', 1],
#  ['this site can t be reachedthe webpage at might be temporarily down or it may have moved permanently to a new web address',
#   1],
#  ['err quic protocol errornullthe webpage at might be temporarily down or it may have moved permanently to a new web address',
#   1],
#  ['var loadtimedataraw textdirection ltr title', 1],
#  ['', 1],
#  ['lzd', 1],
#  ['', 1],
# ...
#   0],
#  ['berantas judi onlinepresiden joko widodo jokowi telah membentuk satuan tugas atau satgas pemberantasan perjudian daring',
#   0],
#  ['melalui keputusan presiden keppres no', 0],
#  ['jokowi menunjuk menkopolhukam ri hadi tjahjanto sebagai kasatgas pemberantasan judi online',
#   0],
#  ['pembentukan satgas ini bertujuan untuk mempercepat pemberantasan kegiatan judi online secara tegas dan terpadu',
#   0],
#  ['selain itu satgas ini juga dibentuk agar bisa mengoptimalkan pencegahan dan penegakan hukum perjudian online secara efektif dan efisien di indonesia',
#   0],
#  ['sebagai langkah awal hadi menyampaikan satgas yang dipimpinnya itu memiliki tiga agenda mulai dari penyitaan sejumlah',
#   0],
#  ['rekening yang terindikasi online oleh bareskrim polri', 0],
#  ['nantinya apabila tidak ada yang melaporkan rekening tersebut maka ribuan rekening itu akan disita untuk masuk ke kantong negara',
#   0],
#  ['selanjutnya memblokir transaksi dana ke dompet digital atau top up terkait gim online di minimarket yang terafiliasi dengan judi online hingga menindak praktik jual beli rekening',
#   0],
#  ['saya minta wakabareskrim termasuk dan wakapuspom tni agar membantu untuk memberantas jual beli rekening tersebut dengan mengarahkan para babinsa dan bhabinkamtibmas ujar hadi di kantornya rabu',
#   0],
#  ['di samping itu polri sebagai tim penegakan hukum judi online mencatat telah menangani sebanyak',
#   0],
#  ['kasus perjudian daring atau judi online selama', 0],
#  ['perinciannya sebanyak', 0],
#  ['kasus dengan', 0],
#  ['tersangka ditetapkan sepanjang', 0],
#  ['sementara untuk penanganan pada sampai bulan april mencapai kasus dengan tersangka mencapai',
#   0],
#  ['tersangka', 0],
#  ['sementara itu menurut data kementerian komunikasi dan informatika menkominfo telah memblokir juta situs judi online dalam periode juli juli',
#   0],
#  ['pemblokiran itu dinilai telah berhasil menghambat perputaran dana di indonesia mencapai ratusan triliun',
#   0],
#  ['dan yang kami lakukan ini mampu menahan hingga dari kemungkinan dampak judi online',
#   0],
#  ['kalau dalam angka kita mampu menyelamatkan atau menahan orang bermain judi hingga senilai rp triliun tutur menkominfo ri budi',
#   0],
#  ['penulis anshary madya sukma editor edi suwiknyo previous sejarah baru dari indonesia africa forum to topaboutprivacy policycode of conductadvertise with uscontact uscareercopyright bisnis indonesia',
#   0],
#  ['', 0],
#  ['satu akun untuk semua akses emailkata sandi lupa kata sandi klik di sini lupa kata sandi klik di sinimasukatau masuk melaluigooglefacebook belum memiliki akun daftar di sini satu akun untuk semua akses nama lengkapemailkata sandiulangi kata sandi daftaratau daftar melaluigooglefacebook sudah memiliki akun masuk di sini konfirmasi emailkami telah mengirimkan link aktivasi melalui email ke rudihamdani gmail',
#   0],
#  ['com', 0],
#  ['klik link aktivasi dan dapatkan akses membaca artikel gratis non laput di koran dan majalah tempojika anda tidak menerima email kirimkan lagi sekarang hasil pencarian pencarian terpopulerpilpres pemilu piala asia mahfud mdcoldplaygibran rakabumingjokowiganjar pranowoanies baswedanprabowo subiantoif notifications powered by izooto',
#   0],
#  ['', 0],
#  ['englishterkiniterpopulertop newspilihan editorpemiluotomotifantarafoto home politikhukumekonomifinansialbisnisbursabumn untuk indonesiametrokriminalitaslintas kotalenggang jakartasepakbolaindonesia internasionalliga inggrisliga spanyolliga italialiga championsliga jermanliga prancisliga liga lainbintangolahragabulutangkisbola baskettenisbalape sportall bumirilis pers anti hoaxantara interaktifmata indonesiaantara doeloeenglish edition antara hukumhadi ungkap judi online slot paling diminati sejak hadi ungkap judi online slot paling diminati sejak selasa april wibmenteri koordinator bidang politik hukum dan keamanan menko polhukam hadi tjahjanto jumpa pers selepas rapat koordinasi membahas pembentukan satuan tugas satgas pemberantasan judi online di kantor kemenko polhukam ri jakarta selasa',
#   0],
#  ['antara genta tenri mawangi pada tahun itu judinya bersifat credit market kemudian pada tahun itu cash market pada tahun sudah masif menggunakan link alternatif',
#   0],
#  ['jakarta antara menteri koordinator bidang politik hukum dan keamanan menko polhukam hadi tjahjanto mengungkap judi online slot yang paling banyak diminati oleh pejudi di indonesia sejak',
#   0],
#  ['hadi menyebutkan ada perubahan tren minat pemain judi online di indonesia yaitu pada tahun dan',
#   0],
#  ['bareskrim badan reserse kriminal polri red', 0],
#  ['menyebutkan sejak sampai dengan tercatat beberapa model', 0],
#  ['pada tahun itu judinya bersifat credit market kemudian pada tahun itu cash market pada tahun sudah masif menggunakan link alternatif server di luar negeri yang paling banyak diminati judi online dengan slot kata hadi saat ditemui selepas rapat koordinasi satuan tugas satgas pemberantasan judi online di kantor kemenko polhukam ri jakarta selasa',
#   0],
#  ['dikatakan bahwa judi online slot paling banyak diminati karena mudah diakses hanya mensyaratkan adanya sambungan internet dan gawai',
#   0],
#  ['ini lebih mudah kapan saja di mana saja', 0],
#  ['artinya kapan saja sambil duduk ini bisa melaksanakan judi online kata hadi',
#   0],
#  ['menko polhukam melanjutkan bahwa pusat pelaporan dan analisis transaksi keuangan ppatk mencatat ada juta pejudi online di indonesia',
#   0],
#  ['sekitar persen bermain di bawah nilai rp ribu', 0],
#  ['meskipun di bawah rp ribu nilai agregat perputaran uang dari judi online di indonesia pada tahun menurut catatan ppatk mencapai rp triliun',
#   0],
#  ['itu tercatat rp triliun', 0],
#  ['itu berasal dari transaksi dan triwulan i tahun tercatat rp triliun', 0],
#  ['ini juga agregat ya kata menko polhukam ri', 0],
#  ['sejauh ini hadi menyebut kementerian komunikasi dan informatika per desember telah menghapus',
#   0],
#  ['konten judi online yang beredar di dunia maya', 0],
#  ['jadi memang sangat besar ya', 0],
#  ['dan server nya ada di luar negeri kata hadi', 0],
#  ['oleh karena itu satgas pemberantasan judi online tidak hanya melibatkan aparat penegak hukum tetapi juga seluruh kementerian lembaga termasuk kementerian luar negeri',
#   0],
#  ['kami akan bikin mou dengan negara lain red', 0],
#  ['yang diperluas', 0],
#  ['bukan hanya tppo tindak pidana perdagangan orang melainkan juga akan bekerja sama bagaimana kejahatan teknologi informasi itu bisa diterapkan dalam kerja sama ini kata hadi tjahjanto menjawab pertanyaan wartawan',
#   0],
#  ['ia menyebutkan negara negara yang menjadi sasaran satgas pemberantasan judi online di antaranya yang ada di asia tenggara',
#   0],
#  ['baca juga pemberantasan judi online dijadikan program keberlanjutanbaca juga menko polhukam godok pembentukan satgas berantas judi onlinehadi menggelar rapat koordinasi pembentukan satgas pemberantasan judi online bersama beberapa pejabat kementerian lembaga di kantor kemenko polhukam ri jakarta selasa',
#   0],
#  ['rapat itu yang merupakan tindak lanjut atas perintah presiden ri joko widodo minggu lalu diikuti oleh menteri komunikasi dan informatika budi arie setiadi jaksa agung sanitiar burhanuddin kepala badan siber dan sandi negara bssn letjen tni purn',
#   0],
#  ['hinsa siburian inspektur jenderal kementerian hukum dan ham ri reynhard silitonga kepala pusat pelaporan dan analisis transaksi keuangan ppatk ivan yustiavandana kepala badan reserse kriminal bareskrim polri komjen pol',
#   0],
#  ['wahyu widada dan ketua dewan komisioner dk otoritas jasa keuangan ojk mahendra siregar',
#   0],
#  ['ini kami sudah buat drafnya kemudian akan kami laporkan kepada bapak presiden untuk segera kami lakukan karena ini hasil dari ratas rapat terbatas kata hadi menjawab pertanyaan wartawan saat ditemui selepas rapat',
#   0],
#  ['pewarta genta tenri mawangieditor d', 0],
ebas visa jam laluaksi pesawat siluman f a australia hingga aerobatik tim jupiter au jam lalukip ubah putusan pasangan bustami fadhil maju di pilkada aceh jam lalukpu banten tetapkan dpt dan paslon cagub cawagub pilkada jam lalusituasi palestina memburuk menlu ri tegaskan dukungan bagi unrwa jam laluri nepal sepakati perjanjian bebas visa jam laluaksi pesawat siluman f a australia hingga aerobatik tim jupiter au jam lalukip ubah putusan pasangan bustami fadhil maju di pilkada aceh jam lalukpu banten tetapkan dpt dan paslon cagub cawagub pilkada jam lalu infografikindonesia boyong medali worldskills competition kemarin kemenangan dramatis le bestia jam lalucara cek dana program indonesia pintar jam laluasal usul boneka labubu jam lalumobil listrik terlaris di indonesia kemarin indonesia boyong medali worldskills competition kemarin kemenangan dramatis le bestia jam lalucara cek dana program indonesia pintar jam laluasal usul boneka labubu jam lalumobil listrik terlaris di indonesia kemarin indonesia boyong medali worldskills competition kemarin terkinitop newsterpopulerpilihan duniateknootomotifwarta bumirilis pers karkhasanti hoaks ...
#   0],
#  ['', 0],
#  ['homeeconomysmart moneybegini cara menghapus akun judi online slotrina anggraeni okezone kamis juni wibshare on facebookshare on twitterwhatsappshare on mailcopy linklink successfully copied ilustrasi cara menghapus akun judi online slot foto freepik share on facebookshare on twitterwhatsappshare on mailcopy link total sharelink successfully copied aaajakarta begini cara menghapus akun judi online slot yang bisa anda lakukan',
#   0],
#  ['apalagi bagi pemain yang sudah tidak ingin bermain judi online terkadang datanya masih disimpan',
#   0],
#  ['baca juga ternyata segini gaji dan tunjangan anggota dpr yang disebut banyak main judi onlinebeberapa data mereka tersimpan di database dipindahkan antar sistem komputer dan bahkan dapat dibagikan ke salah satu perusahaan',
#   0],
#  ['tentunya ini merugikan pengguna', 0],
#  ['untuk itu begini cara menghapus akun judi online slot yang bisa anda lakukan adalah dengan menggunakan aplikasi rightly protect',
#   0],
#  ['dengan rightly protect anda dapat menghapus data anda dari situs perjudian mana pun dan bahkan dari perusahaan lain sekaligus',
#   0],
#  ['baca juga blokir rekening judi online ojk koordinasi dengan kominfoatau anda bisa dengan langsung menelepon pihak perusahaan judi online untuk meminta menghapus data akun pribadi',
#   0],
#  ['selain itu anda bisa melakukan pemblokiran akun judi online', 0],
#  ['berikut langkahnya', 0],
#  ['blokir situs slot melalui smartphonepertama buka laman aplikasi google chromecari ikon tiga titik vertikal yang terletak pada pojok kanan atas lalu klik opsi setelanscroll dan temukan menu bernama opsi setelah situs lalu pilih menu pop up dan pengalihan setelah itu tinggal aktifkan toggle blokir maka situs judi slot sudah otomatis terblokir okezone',
#   0],
#  ['complease allow ads on our sitelooks like you re using an ad blocker', 0],
#  ['we rely on advertising to help fund our site', 0],
#  ['allow ads', 0],
#  ['', 0],
#  ['menuju konten utama tirto', 0],
#  ['id pencarianperiksa faktanewsdiajengbisnisberandalatest newsperiksa faktanewsflash newsnews plusdecodemozaikmesin waktumirosoperspektifwawancara khususbisnisinsiderside jobgearboxbyteedusainsgwstirtoecovisualvideovidproesai fotoinfografikdiajengfor your pemiluinceptioncontact usindeksmode gelapartikel teks besarberandanewsflash newsapakah judi online itu legal dan kenapa orang suka main slot penjelasan mengenai judi online di indonesia apakah legal atau tidak dan alasan kenapa orang suka main slot atau judi online',
#   0],
#  ['kontributor bintang pamungkasterbit jun wib waktu baca menitbagikanwhatsappwhatsappxx twitter facebookfacebooklinkedinlinkedinemailsejumlah barang bukti ditunjukkan saat pengungkapan kasus judi online sepak bola di polresta bogor kota kedung halang kota bogor jawa barat jumat malam',
#   0],
#  ['polisi mengangkap tersangka beserta barang bukti dalam kasus judi online sepak bola di perumahan bnr kota bogor',
#   0],
#  ['antarafoto yulius satria wijaya', 0],
#  ['tirto', 0],
#  ['id praktik judi online masih merajalela di indonesia', 0],
#  ['tak hanya berdampak negatif pada diri sendiri namun judi online juga bisa berdampak pada orang orang terdekat terutama keluarga',
#   0],
#  ['seperti kasus baru baru ini di mojokerto seorang polwan membakar suaminya yang juga seorang polisi akibat judi online',
#   0],
#  ['advertisementkasus tersebut bermula saat pelaku briptu fn mendapati saldo gaji ke suaminya briptu rdw berkurang akibat judi online',
#   0],
#  ['gpt inline passbacksetelah didalami lebih lanjut motif pembakaran yang dilakukan fn disebabkan suaminya rdw sering melakukan praktik judi online',
#   0],
#  ...]

# %%
final_df = pd.DataFrame(
	data = splitted_texts,
	columns = ["text", "is_gambling_site"]
)

final_df
# Out:
#                                                    text  is_gambling_site
# 0     daftarmasuk hot games slots casino sports arca...                 1
# 1     pemberitahuan pemeliharaan terjadwal sbo virtu...                 1
# 2     selama waktu ini sbo virtual sports permainan ...                 1
# 3     kami memohon maaf atas ketidaknyamanan yang mu...                 1
# 4     pemeliharaan terjadwal ion slot pada dari am s...                 1
# ...                                                 ...               ...
# 1301  republika tvihramrejabarrejogjaretizenbuku rep...                 0
# 1302  balibaliexpressradar surabayaradar gresikradar...                 0
# 1303  dialogis lebih efektifpemerintah mengeklaim di...                 0
# 1304  var eo subcat const base url const asset url c...                 0
# 1305  bbc news indonesialangsung ke kontenkategoribe...                 0
#
# [1306 rows x 2 columns]

# %% [markdown]
# After splitting the text, it turns out there are some problems:
# - There are some rows contain a few characters and most of them are don't represent either gambling and non-gambling sites
# - There are some rows with empty string
#
# > To address these issues I will create a function to drop text that have characters less than 30 from the list

# %%
final_df = final_df.loc[final_df["text"].str.len()>=30]
final_df
# Out:
#                                                    text  is_gambling_site
# 0     daftarmasuk hot games slots casino sports arca...                 1
# 1     pemberitahuan pemeliharaan terjadwal sbo virtu...                 1
# 2     selama waktu ini sbo virtual sports permainan ...                 1
# 3     kami memohon maaf atas ketidaknyamanan yang mu...                 1
# 4     pemeliharaan terjadwal ion slot pada dari am s...                 1
# ...                                                 ...               ...
# 1301  republika tvihramrejabarrejogjaretizenbuku rep...                 0
# 1302  balibaliexpressradar surabayaradar gresikradar...                 0
# 1303  dialogis lebih efektifpemerintah mengeklaim di...                 0
# 1304  var eo subcat const base url const asset url c...                 0
# 1305  bbc news indonesialangsung ke kontenkategoribe...                 0
#
# [1081 rows x 2 columns]

# %%
final_df.to_csv("dataset/cleaned_text.csv", index=False)
